# %%
# !pip3 install textblob
# !pip3 install spacy
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.4)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import requests
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
from transformers import pipeline
from nltk import download
from nltk.tokenize import sent_tokenize
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd
import spacy
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
download('vader_lexicon')
download('punkt')

nlp = spacy.load("en_core_web_sm")

urls = [
    'https://www.robomarkets.com/blog/stock-market/boeing-stock-analysis-and-forecast/',
    'https://www.robomarkets.com/blog/stock-market/general-motors-stock-analysis-and-outlook/'
]
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def scrape_content(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    paragraphs = soup.find_all('p')
    content = ' '.join([para.get_text() for para in paragraphs if para.get_text()])
    return content

# %%
contents = [scrape_content(url) for url in urls]

vader_analyzer = SentimentIntensityAnalyzer()
bert_analyzer = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
def analyze_sentiment(content):
    sentences = sent_tokenize(content)
    sentiment_scores = []
    for sentence in sentences:
        vader_score = vader_analyzer.polarity_scores(sentence)
        textblob_score = TextBlob(sentence).sentiment.polarity
        bert_score = bert_analyzer(sentence)[0]
        sentiment_scores.append((sentence, vader_score, textblob_score, bert_score))
    return sentiment_scores


all_sentiments = []
for content in contents:
    sentiments = analyze_sentiment(content)
    all_sentiments.append(sentiments)

# %%
def extract_entities_and_sentiment(sentiments):
    entity_sentiments = []
    for sentence, vader_score, textblob_score, bert_score in sentiments:
        doc = nlp(sentence)
        for ent in doc.ents:
            entity_sentiments.append((ent.text, ent.label_, vader_score['compound'], textblob_score, bert_score['score']))
    return entity_sentiments

all_entity_sentiments = []
for sentiments in all_sentiments:
    entity_sentiments = extract_entities_and_sentiment(sentiments)
    all_entity_sentiments.append(entity_sentiments)

# %%
def perform_topic_modeling(contents, n_topics=5):
    vectorizer = CountVectorizer(stop_words='english')
    dtm = vectorizer.fit_transform(contents)
    lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
    lda.fit(dtm)
    return lda, vectorizer

lda, vectorizer = perform_topic_modeling(contents)
topics = lda.transform(vectorizer.transform(contents))

# %%
def perform_topic_modeling(contents, n_topics=5):
    vectorizer = CountVectorizer(stop_words='english')
    dtm = vectorizer.fit_transform(contents)
    lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
    lda.fit(dtm)
    return lda, vectorizer

lda, vectorizer = perform_topic_modeling(contents)
topics = lda.transform(vectorizer.transform(contents))

# %%
for i, sentiments in enumerate(all_sentiments):
    print(f'Detailed sentiment scores for Blog {i+1}:')
    for sentence, vader_score, textblob_score, bert_score in sentiments:
        print(f'Sentence: {sentence}')
        print(f'VADER scores: {vader_score}')
        print(f'TextBlob polarity: {textblob_score}')
        print(f'BERT score: {bert_score}')
        print('-' * 80)

for i, entity_sentiments in enumerate(all_entity_sentiments):
    print(f'Entity sentiments for Blog {i+1}:')
    for ent_text, ent_label, vader_score, textblob_score, bert_score in entity_sentiments:
        print(f'Entity: {ent_text} ({ent_label})')
        print(f'VADER score: {vader_score}')
        print(f'TextBlob polarity: {textblob_score}')
        print(f'BERT score: {bert_score}')
        print('-' * 80)
# Out:
# Detailed sentiment scores for Blog 1:
# Sentence: On 2 January 2024, Boeing Company’s stock surged to 267 USD per unit, reflecting a 42.5% return in just two months.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.8579011559486389}
# --------------------------------------------------------------------------------
# Sentence: However, by 22 January 2024, the share price had plummeted by over 19%, reaching 215 USD.
# VADER scores: {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.4588}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9970587491989136}
# --------------------------------------------------------------------------------
# Sentence: In this article, we aim to explain the reasons behind the decline in the stock value of one of the world’s largest aircraft, space, and military machinery manufacturers.
# VADER scores: {'neg': 0.0, 'neu': 0.918, 'pos': 0.082, 'compound': 0.34}
# TextBlob polarity: -0.25
# BERT score: {'label': 'NEGATIVE', 'score': 0.9245975017547607}
# --------------------------------------------------------------------------------
# Sentence: We will examine the company’s financial reports, conduct a technical analysis of its stock, and share experts’ forecasts for the stock outlook for 2024.
# VADER scores: {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.296}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9915067553520203}
# --------------------------------------------------------------------------------
# Sentence: The Boeing Company released its Q3 2023 report on 25 October 2023.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9565975069999695}
# --------------------------------------------------------------------------------
# Sentence: Revenue from July to September rose by 13.46% to 18.1 billion USD compared to the same period in 2022.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.3
# BERT score: {'label': 'POSITIVE', 'score': 0.6971259713172913}
# --------------------------------------------------------------------------------
# Sentence: Net loss decreased by 50.48%, down to 1.64 billion USD or 2.70 USD per share.
# VADER scores: {'neg': 0.131, 'neu': 0.743, 'pos': 0.126, 'compound': -0.0258}
# TextBlob polarity: -0.1851851851851852
# BERT score: {'label': 'NEGATIVE', 'score': 0.999354898929596}
# --------------------------------------------------------------------------------
# Sentence: The company’s profitability ratios for Q3 2023 are not likely to please investors and analysts: the operating margin was −1.93%, and the profit margin reached −3.74%.
# VADER scores: {'neg': 0.065, 'neu': 0.725, 'pos': 0.211, 'compound': 0.5327}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.999747097492218}
# --------------------------------------------------------------------------------
# Sentence: Expenses amounted to 18.7 billion USD, exceeding revenue by 687 million USD.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9000501036643982}
# --------------------------------------------------------------------------------
# Sentence: The company must borrow funds to support its operations.
# VADER scores: {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9945310950279236}
# --------------------------------------------------------------------------------
# Sentence: The Boeing Company reported a negative annual profit in Q4 2019 and has been unable to return to positive territory since then.
# VADER scores: {'neg': 0.131, 'neu': 0.638, 'pos': 0.23, 'compound': 0.4215}
# TextBlob polarity: -0.19090909090909092
# BERT score: {'label': 'NEGATIVE', 'score': 0.9995853304862976}
# --------------------------------------------------------------------------------
# Sentence: The financial challenges began after the crash of a 737 MAX 8 on 10 March 2019, leading to the ensuing ban on the 737 MAX aircraft in numerous countries.
# VADER scores: {'neg': 0.199, 'neu': 0.759, 'pos': 0.041, 'compound': -0.7184}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9977140426635742}
# --------------------------------------------------------------------------------
# Sentence: Subsequently, a crisis emerged due to the COVID-19 pandemic, pushing many air travel and aircraft industry representatives to the brink of collapse.
# VADER scores: {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'compound': -0.8074}
# TextBlob polarity: 0.125
# BERT score: {'label': 'NEGATIVE', 'score': 0.999656081199646}
# --------------------------------------------------------------------------------
# Sentence: The Boeing Company had to borrow funds, thereby increasing the debt burden.
# VADER scores: {'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'compound': -0.6597}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9969316720962524}
# --------------------------------------------------------------------------------
# Sentence: In Q1 2019, its long-term debt stood at 11.3 billion USD; by Q4 2020, it reached the highest value of 61.9 billion USD.
# VADER scores: {'neg': 0.095, 'neu': 0.76, 'pos': 0.144, 'compound': 0.0772}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9239501357078552}
# --------------------------------------------------------------------------------
# Sentence: In Q2 2019, all debt obligations exceeded the company’s total assets, and the situation has not improved.As for The Boeing Company’s stock, it headed down on 13 February 2020, losing nearly 75% by 18 March 2020 and dropping to a low of 89 USD.
# VADER scores: {'neg': 0.15, 'neu': 0.814, 'pos': 0.035, 'compound': -0.6705}
# TextBlob polarity: -0.013888888888888895
# BERT score: {'label': 'NEGATIVE', 'score': 0.9996864795684814}
# --------------------------------------------------------------------------------
# Sentence: To better understand the scale of challenges The Boeing Company has faced over the past few years, we will examine the statistics on airliner order volumes and deliveries from January 2018 to December 2023.In 2018, there were 1,090 orders for airliners, but the actual deliveries amounted to 806 units.
# VADER scores: {'neg': 0.0, 'neu': 0.938, 'pos': 0.062, 'compound': 0.2732}
# TextBlob polarity: 0.012499999999999997
# BERT score: {'label': 'NEGATIVE', 'score': 0.875400722026825}
# --------------------------------------------------------------------------------
# Sentence: In 2019, the number of orders decreased to 246 aircraft, while deliveries surpassed the order figures, thanks to a large order in 2018, reaching 380 units.
# VADER scores: {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'compound': 0.6124}
# TextBlob polarity: 0.0047619047619047545
# BERT score: {'label': 'POSITIVE', 'score': 0.9713989496231079}
# --------------------------------------------------------------------------------
# Sentence: In 2020, with the announcement of the COVID-19 pandemic, the number of orders decreased to 184 aircraft, and deliveries dropped to 157.
# VADER scores: {'neg': 0.0, 'neu': 0.942, 'pos': 0.058, 'compound': 0.0772}
# TextBlob polarity: -0.4
# BERT score: {'label': 'NEGATIVE', 'score': 0.9980769157409668}
# --------------------------------------------------------------------------------
# Sentence: In 2021, the situation changed dramatically, with orders reaching 909 units and deliveries standing at 340.
# VADER scores: {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'compound': 0.2023}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.5204876661300659}
# --------------------------------------------------------------------------------
# Sentence: The positive trend persisted in 2022, with 935 units ordered and 480 delivered.
# VADER scores: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5574}
# TextBlob polarity: 0.22727272727272727
# BERT score: {'label': 'POSITIVE', 'score': 0.995943009853363}
# --------------------------------------------------------------------------------
# Sentence: In 2023, orders surpassed the 2018 record, reaching 1,314 aircraft, while deliveries increased to only 528.
# VADER scores: {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.4404}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.8362426161766052}
# --------------------------------------------------------------------------------
# Sentence: Want to trade stocks without commission?
# VADER scores: {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.0772}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9983626008033752}
# --------------------------------------------------------------------------------
# Sentence: Gain access to over 1000 US stocks for commission-free trading on the R StocksTrader platform The Dubai Airshow, one of the world’s largest aerospace exhibitions, took place in Dubai from 13 to 17 November 2023.
# VADER scores: {'neg': 0.0, 'neu': 0.907, 'pos': 0.093, 'compound': 0.5267}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9983773231506348}
# --------------------------------------------------------------------------------
# Sentence: On the inaugural day, Boeing secured six deals with airlines to deliver 269 planes.
# VADER scores: {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.4019}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9698579907417297}
# --------------------------------------------------------------------------------
# Sentence: The most significant order that day came from Emirates for 35 units of Boeing 777-8, 55 units of Boeing 777-9, and 35 units of Boeing 787.
# VADER scores: {'neg': 0.0, 'neu': 0.923, 'pos': 0.077, 'compound': 0.2716}
# TextBlob polarity: 0.4375
# BERT score: {'label': 'NEGATIVE', 'score': 0.884709894657135}
# --------------------------------------------------------------------------------
# Sentence: The total value of the order reached 52 billion USD, marking the largest deal in the commercial segment based on the number of planes ordered by one airline at the airshow.
# VADER scores: {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'compound': 0.4767}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.8991870880126953}
# --------------------------------------------------------------------------------
# Sentence: On the second day of the Dubai Airshow, the company received orders for another 36 units.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.7123515009880066}
# --------------------------------------------------------------------------------
# Sentence: Boeing’s major competitor is Airbus Group SE, a European multinational corporation that designs, manufactures, and sells civil and military aviation products worldwide.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: -0.012500000000000002
# BERT score: {'label': 'POSITIVE', 'score': 0.9441977739334106}
# --------------------------------------------------------------------------------
# Sentence: Below, we have provided an infographic of Airbus Group SE orders and deliveries from January 2018 to December 2023 inclusive.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9840360283851624}
# --------------------------------------------------------------------------------
# Sentence: Unlike The Boeing Company, which has a significant backlog of deliveries compared to orders, Airbus Group SE has seen deliveries exceeding orders from 2018 to 2022.
# VADER scores: {'neg': 0.0, 'neu': 0.93, 'pos': 0.07, 'compound': 0.2023}
# TextBlob polarity: 0.375
# BERT score: {'label': 'POSITIVE', 'score': 0.8422392010688782}
# --------------------------------------------------------------------------------
# Sentence: The reason is the accumulation of old orders.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.1
# BERT score: {'label': 'NEGATIVE', 'score': 0.9954149723052979}
# --------------------------------------------------------------------------------
# Sentence: Based on the 2023 results, demand for the European company’s airliners has sharply increased, reaching a record value of 2,094 units.
# VADER scores: {'neg': 0.063, 'neu': 0.672, 'pos': 0.265, 'compound': 0.5859}
# TextBlob polarity: -0.0625
# BERT score: {'label': 'POSITIVE', 'score': 0.9988523721694946}
# --------------------------------------------------------------------------------
# Sentence: While these two aircraft industry representatives had their deliveries at nearly the same level until 2019, The Boeing Company began to lag in 2019 and still has not caught up with its competitor.
# VADER scores: {'neg': 0.07, 'neu': 0.93, 'pos': 0.0, 'compound': -0.34}
# TextBlob polarity: 0.05
# BERT score: {'label': 'NEGATIVE', 'score': 0.9996466636657715}
# --------------------------------------------------------------------------------
# Sentence: Nevertheless, Airbus Group SE received orders for only 66 planes at the Dubai Airshow, considerably less than the US company.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: -0.08333333333333333
# BERT score: {'label': 'NEGATIVE', 'score': 0.999270498752594}
# --------------------------------------------------------------------------------
# Sentence: Boeing Company’s stock started 2024 with a decline.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9958581328392029}
# --------------------------------------------------------------------------------
# Sentence: The primary reason for investor sell-offs is airlines’ complaints about aircraft quality.
# VADER scores: {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'compound': -0.4019}
# TextBlob polarity: 0.4
# BERT score: {'label': 'NEGATIVE', 'score': 0.9957685470581055}
# --------------------------------------------------------------------------------
# Sentence: According to the BBC, a bolt with a missing nut was discovered in the rudder control system on a 737 MAX on 28 December 2023.
# VADER scores: {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'compound': -0.296}
# TextBlob polarity: -0.2
# BERT score: {'label': 'NEGATIVE', 'score': 0.9973012804985046}
# --------------------------------------------------------------------------------
# Sentence: Subsequently, the manufacturer urged all airlines to inspect aircraft of this model available in their fleets.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.2
# BERT score: {'label': 'NEGATIVE', 'score': 0.9725563526153564}
# --------------------------------------------------------------------------------
# Sentence: Despite Boeing Company’s positive end to 2023 (highlighted by orders at the Dubai Airshow and deliveries to China), investors responded to new challenges in early 2024, with the stock price plummeting from 261 USD on 2 January to 244 USD per unit on 3 January.
# VADER scores: {'neg': 0.065, 'neu': 0.907, 'pos': 0.029, 'compound': -0.3867}
# TextBlob polarity: 0.15454545454545454
# BERT score: {'label': 'NEGATIVE', 'score': 0.9917494058609009}
# --------------------------------------------------------------------------------
# Sentence: A more serious incident occurred on 5 January when a fuselage door plug detached on a 737 Max 9 aircraft owned by Alaska Airlines, leading to rapid airplane decompression.
# VADER scores: {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'compound': -0.2716}
# TextBlob polarity: 0.08333333333333334
# BERT score: {'label': 'NEGATIVE', 'score': 0.9993001222610474}
# --------------------------------------------------------------------------------
# Sentence: Fortunately, no one was injured.
# VADER scores: {'neg': 0.62, 'neu': 0.38, 'pos': 0.0, 'compound': -0.5994}
# TextBlob polarity: -0.2
# BERT score: {'label': 'POSITIVE', 'score': 0.9971963167190552}
# --------------------------------------------------------------------------------
# Sentence: Following the incident, the US Federal Aviation Administration (FAA) temporarily grounded the 737 Max 9 airplanes operated in the country, jeopardising deliveries to China.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9980762004852295}
# --------------------------------------------------------------------------------
# Sentence: The Alaska Airlines incident happened on a Friday evening when the trading session was closed.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: -0.1
# BERT score: {'label': 'NEGATIVE', 'score': 0.995518147945404}
# --------------------------------------------------------------------------------
# Sentence: However, on Monday 8 January, trading opened with an 8.3% drop in Boeing Company’s stock value, down to 228.00 USD.
# VADER scores: {'neg': 0.098, 'neu': 0.791, 'pos': 0.112, 'compound': 0.0772}
# TextBlob polarity: -0.15555555555555559
# BERT score: {'label': 'NEGATIVE', 'score': 0.9965404272079468}
# --------------------------------------------------------------------------------
# Sentence: By 16 January, the shares reached a low of 199.50 USD, marking a 19.5% decline.
# VADER scores: {'neg': 0.134, 'neu': 0.637, 'pos': 0.229, 'compound': 0.128}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9992498755455017}
# --------------------------------------------------------------------------------
# Sentence: According to Air Current, the incident aboard the Boeing 737 Max 9 involved a new aircraft delivered to Alaska Airlines on 31 October 2023.
# VADER scores: {'neg': 0.0, 'neu': 0.95, 'pos': 0.05, 'compound': 0.0258}
# TextBlob polarity: 0.06818181818181818
# BERT score: {'label': 'NEGATIVE', 'score': 0.9791088104248047}
# --------------------------------------------------------------------------------
# Sentence: This information suggests that the issue lies not in the aircraft’s wear and tear but in its assembly’s quality.
# VADER scores: {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'compound': -0.2263}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9519588351249695}
# --------------------------------------------------------------------------------
# Sentence: It remains uncertain whether the airline will seek an alternative manufacturer.
# VADER scores: {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.296}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9992192983627319}
# --------------------------------------------------------------------------------
# Sentence: It is worth noting that only two mass-scale manufacturers of narrow-body medium-range aircraft exist globally, namely The Boeing Company and Airbus Group SE.
# VADER scores: {'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'compound': 0.2263}
# TextBlob polarity: 0.09999999999999999
# BERT score: {'label': 'NEGATIVE', 'score': 0.824809730052948}
# --------------------------------------------------------------------------------
# Sentence: Furthermore, it is essential to note that airlines anticipate manufacturers fulfilling their orders over several years.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.6238307952880859}
# --------------------------------------------------------------------------------
# Sentence: Suppose an order for Boeing 737 aircraft with potential delivery in several years is revoked.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.999458372592926}
# --------------------------------------------------------------------------------
# Sentence: In that case, placing a new order with an alternative manufacturer will probably result in an even lengthier fulfilment period.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.13636363636363635
# BERT score: {'label': 'NEGATIVE', 'score': 0.999071478843689}
# --------------------------------------------------------------------------------
# Sentence: Such delays may lead to the airline losing its market share.
# VADER scores: {'neg': 0.188, 'neu': 0.652, 'pos': 0.159, 'compound': -0.1027}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9997816681861877}
# --------------------------------------------------------------------------------
# Sentence: Furthermore, transitioning to new aircraft models might require pilots and maintenance staff to undergo retraining.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.13636363636363635
# BERT score: {'label': 'NEGATIVE', 'score': 0.9991918206214905}
# --------------------------------------------------------------------------------
# Sentence: Following each incident, an investigation occurs, with the aircraft manufacturer addressing all defects at its expense, which implies that all aircraft issues will likely be resolved by the time the order placed in 2023 is fulfilled.
# VADER scores: {'neg': 0.067, 'neu': 0.821, 'pos': 0.112, 'compound': 0.2023}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9846188426017761}
# --------------------------------------------------------------------------------
# Sentence: Given the above, the likelihood of airlines refraining from purchasing Boeing aircraft appears low.
# VADER scores: {'neg': 0.139, 'neu': 0.861, 'pos': 0.0, 'compound': -0.2732}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9995500445365906}
# --------------------------------------------------------------------------------
# Sentence: Boeing 737 MAX aircraft deliveries to China were suspended in March 2019 after two crashes in Indonesia and Ethiopia resulted in 346 fatalities.
# VADER scores: {'neg': 0.25, 'neu': 0.75, 'pos': 0.0, 'compound': -0.7906}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9989460110664368}
# --------------------------------------------------------------------------------
# Sentence: In January 2023, the Chinese regulator permitted national airlines to operate the Boeing 737 MAX 8 airplanes already in their fleet.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9549623727798462}
# --------------------------------------------------------------------------------
# Sentence: Since then, Boeing has been striving to resume deliveries of accumulated orders to its Chinese clients.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9969723224639893}
# --------------------------------------------------------------------------------
# Sentence: In July, David Calhoun, the company’s CEO, informed that Boeing had 85 aircraft in inventory intended for Chinese companies, and that new buyers from other countries were found for another 55 units designated initially for delivery to China.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0028409090909090884
# BERT score: {'label': 'NEGATIVE', 'score': 0.9965541362762451}
# --------------------------------------------------------------------------------
# Sentence: In December 2023, the US aircraft manufacturer obtained approval from the Chinese regulator for aircraft deliveries, with the first Boeing airplane delivery to China taking place in that very month.
# VADER scores: {'neg': 0.0, 'neu': 0.903, 'pos': 0.097, 'compound': 0.4767}
# TextBlob polarity: 0.15
# BERT score: {'label': 'POSITIVE', 'score': 0.9693330526351929}
# --------------------------------------------------------------------------------
# Sentence: However, following the incident with the Alaska Airlines airplane, the Chinese regulator directed local airlines to conduct additional safety inspections of the Boeing 737 MAX aircraft in their fleets, suspending new deliveries to China.
# VADER scores: {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.4215}
# TextBlob polarity: 0.03409090909090909
# BERT score: {'label': 'NEGATIVE', 'score': 0.9979922771453857}
# --------------------------------------------------------------------------------
# Sentence: Since 30 March 2020, Boeing Company’s stock has traded between 120 USD and 260 USD.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.8020995259284973}
# --------------------------------------------------------------------------------
# Sentence: Investors actively buy these shares at the price drop to 120 USD, as they consider this price level acceptable for investing in the company.When approaching 260 USD, the stock sees an increase in sales.
# VADER scores: {'neg': 0.052, 'neu': 0.721, 'pos': 0.226, 'compound': 0.7184}
# TextBlob polarity: -0.06666666666666667
# BERT score: {'label': 'POSITIVE', 'score': 0.9773954749107361}
# --------------------------------------------------------------------------------
# Sentence: With the aircraft maker’s debts exceeding its assets, investors likely view 260 USD as the maximum price for its shares.
# VADER scores: {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.4404}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9702264666557312}
# --------------------------------------------------------------------------------
# Sentence: In December 2023, the stock quotes attempted to break above the resistance level of 260 USD but failed due to the 737 Max 9 incident, dropping the share price to 200 USD.
# VADER scores: {'neg': 0.123, 'neu': 0.8, 'pos': 0.077, 'compound': -0.3919}
# TextBlob polarity: -0.20833333333333334
# BERT score: {'label': 'NEGATIVE', 'score': 0.9993112087249756}
# --------------------------------------------------------------------------------
# Sentence: The Boeing Company’s stock purchases resumed on 17 January, enabling the quotes to rise to 215 USD by 22 January.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.6442034244537354}
# --------------------------------------------------------------------------------
# Sentence: If investors believe the company can address aircraft quality issues, stock purchases will likely gain momentum, with the quotes testing the resistance level of 260 USD again.
# VADER scores: {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.5267}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9942609071731567}
# --------------------------------------------------------------------------------
# Sentence: Its breakthrough may serve as a catalyst for further price growth to the next resistance level of 300 USD.
# VADER scores: {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.3818}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9820947051048279}
# --------------------------------------------------------------------------------
# Sentence: Technical analysis of Boeing Co.* Gain access to the world of investments through one application Discover a new level of trading with R MobileTrader.
# VADER scores: {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.5267}
# TextBlob polarity: 0.06818181818181818
# BERT score: {'label': 'POSITIVE', 'score': 0.9860144853591919}
# --------------------------------------------------------------------------------
# Sentence: Click on the button and install the award-winning app The growth in orders in 2023 will likely create favourable conditions for Boeing Company’s revenue increase.
# VADER scores: {'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'compound': 0.7184}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.994255006313324}
# --------------------------------------------------------------------------------
# Sentence: However, significant changes in financial statistics will probably depend on optimising business processes, enhancing aircraft assembly quality, and completing defence orders, which account for most losses.The resumption of the US aircraft manufacturer’s product deliveries to China may also increase company orders.
# VADER scores: {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'compound': 0.7351}
# TextBlob polarity: 0.2916666666666667
# BERT score: {'label': 'POSITIVE', 'score': 0.9711076021194458}
# --------------------------------------------------------------------------------
# Sentence: Given the above information, it is fair to presume that The Boeing Company has the potential to improve its financial position, although it is unlikely to turn profitable in 2024.
# VADER scores: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.7964}
# TextBlob polarity: 0.039999999999999994
# BERT score: {'label': 'NEGATIVE', 'score': 0.9887799024581909}
# --------------------------------------------------------------------------------
# Sentence: More time is probably needed for a corporation of this scale to achieve net profit.
# VADER scores: {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.4404}
# TextBlob polarity: 0.25
# BERT score: {'label': 'NEGATIVE', 'score': 0.9985472559928894}
# --------------------------------------------------------------------------------
# Sentence: As for force majeure events, another aviation incident could be considered as such in this forecast.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.98263019323349}
# --------------------------------------------------------------------------------
# Sentence: Open Trading Account * – Past performance is not a reliable indicator of future results or future performance.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: -0.0625
# BERT score: {'label': 'NEGATIVE', 'score': 0.9997867941856384}
# --------------------------------------------------------------------------------
# Sentence: The material presented and the information contained herein is for information purposes only and in no way should be considered as the provision of investment advice for the purposes of Investment Firms Law 87(I)/2017 of the Republic of Cyprus or any other form of personal advice or recommendation, which relates to certain types of transactions with certain types of financial instruments.
# VADER scores: {'neg': 0.034, 'neu': 0.901, 'pos': 0.065, 'compound': 0.25}
# TextBlob polarity: 0.05059523809523809
# BERT score: {'label': 'NEGATIVE', 'score': 0.9926706552505493}
# --------------------------------------------------------------------------------
# Sentence: The stock charts in this article are provided by the TradingView platform, which offers a wide range of tools for analysing the financial markets.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.961880087852478}
# --------------------------------------------------------------------------------
# Sentence: It is a convenient, high-tech online market data charting service that allows users to perform technical analysis, research financial data, and communicate with other traders and investors.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: -0.041666666666666664
# BERT score: {'label': 'POSITIVE', 'score': 0.9972672462463379}
# --------------------------------------------------------------------------------
# Sentence: Get the latest Robinhood Markets stock forecast for 2024.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.5
# BERT score: {'label': 'NEGATIVE', 'score': 0.9704407453536987}
# --------------------------------------------------------------------------------
# Sentence: Read technical and fundamental analysis of HOOD.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9961062073707581}
# --------------------------------------------------------------------------------
# Sentence: View a live chart of Robinhood Markets stock.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.13636363636363635
# BERT score: {'label': 'POSITIVE', 'score': 0.9417025446891785}
# --------------------------------------------------------------------------------
# Sentence: Read global IPO market analysis and forecasts for 2024.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9678098559379578}
# --------------------------------------------------------------------------------
# Sentence: Find out the most anticipated IPOs in 2024.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.5
# BERT score: {'label': 'POSITIVE', 'score': 0.9359868168830872}
# --------------------------------------------------------------------------------
# Sentence: Learn about the IPO market trends and risks in 2024.
# VADER scores: {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'compound': -0.2732}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9956604838371277}
# --------------------------------------------------------------------------------
# Sentence: Find out the pros and cons of Acuity Trading's analytical tools: Research Terminal, AnalysisIQ, AssetIQ, NewsIQ, Corporate Calendar, and Economic Calendar.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.1
# BERT score: {'label': 'POSITIVE', 'score': 0.9503617286682129}
# --------------------------------------------------------------------------------
# Sentence: Get the latest General Motors stock forecast for 2024.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.275
# BERT score: {'label': 'NEGATIVE', 'score': 0.9911940693855286}
# --------------------------------------------------------------------------------
# Sentence: Read technical and fundamental analysis of GM.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9978578686714172}
# --------------------------------------------------------------------------------
# Sentence: View a live chart of General Motors stock.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.09318181818181819
# BERT score: {'label': 'POSITIVE', 'score': 0.5023815035820007}
# --------------------------------------------------------------------------------
# Sentence: What was the price of silver (XAG/USD) in 2023?
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9923932552337646}
# --------------------------------------------------------------------------------
# Sentence: What factors influenced the rate of silver?
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9817332029342651}
# --------------------------------------------------------------------------------
# Sentence: What are the forecasts for silver in 2024?
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9874047636985779}
# --------------------------------------------------------------------------------
# Sentence: Top 5 biotech stocks for 2023: SLNO, AMAM, EYPT, IMGN, GYRE.
# VADER scores: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.2023}
# TextBlob polarity: 0.5
# BERT score: {'label': 'POSITIVE', 'score': 0.9815215468406677}
# --------------------------------------------------------------------------------
# Sentence: Read the biotechnology sector forecast for 2024.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9273315668106079}
# --------------------------------------------------------------------------------
# Sentence: Find out how to invest in biotech stocks.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9938099980354309}
# --------------------------------------------------------------------------------
# Sentence: Get the latest Boeing stock forecast for 2024.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.5
# BERT score: {'label': 'NEGATIVE', 'score': 0.9791412949562073}
# --------------------------------------------------------------------------------
# Sentence: Read technical and fundamental analysis of BA.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9964343309402466}
# --------------------------------------------------------------------------------
# Sentence: View a live chart of Boeing stock.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.13636363636363635
# BERT score: {'label': 'NEGATIVE', 'score': 0.6043918132781982}
# --------------------------------------------------------------------------------
# Sentence: Get the latest Mullen Automotive stock forecast for 2024.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.5
# BERT score: {'label': 'NEGATIVE', 'score': 0.9717130064964294}
# --------------------------------------------------------------------------------
# Sentence: Read technical and fundamental analysis of MULN.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9928035140037537}
# --------------------------------------------------------------------------------
# Sentence: View a live chart of Mullen Automotive stock.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.13636363636363635
# BERT score: {'label': 'POSITIVE', 'score': 0.8267425894737244}
# --------------------------------------------------------------------------------
# Sentence: RoboMarkets Ltd is a European broker regulated by the CySEC, license No.
# VADER scores: {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.296}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9769171476364136}
# --------------------------------------------------------------------------------
# Sentence: 191/13.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.7968927025794983}
# --------------------------------------------------------------------------------
# Sentence: RoboMarkets Ltd provides financial services only to the residents of the EU/EEA countries.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9139487147331238}
# --------------------------------------------------------------------------------
# Sentence: Disclaimer Any information contained in this site's articles is based on the authors' personal opinion.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9947934746742249}
# --------------------------------------------------------------------------------
# Sentence: These articles shall not be treated as a trading advice or call to action.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.1
# BERT score: {'label': 'NEGATIVE', 'score': 0.98848956823349}
# --------------------------------------------------------------------------------
# Sentence: The authors of the articles or RoboMarkets company shall not be held liable for the results of the trades arising from relying upon opinions and reviews contained herein.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: -0.1
# BERT score: {'label': 'NEGATIVE', 'score': 0.9934145212173462}
# --------------------------------------------------------------------------------
# Sentence: All legal rights of publications hosted on this website are protected by the international intellectual property legislations.
# VADER scores: {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.7717}
# TextBlob polarity: 0.16666666666666666
# BERT score: {'label': 'NEGATIVE', 'score': 0.8700925707817078}
# --------------------------------------------------------------------------------
# Sentence: Using any audio, video, and text materials is permitted only if there is a direct link to source materials.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.05
# BERT score: {'label': 'NEGATIVE', 'score': 0.9939051270484924}
# --------------------------------------------------------------------------------
# Detailed sentiment scores for Blog 2:
# Sentence: The global automotive industry is undergoing significant changes, with more new players eager to compete with eminent giants emerging.
# VADER scores: {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.552}
# TextBlob polarity: 0.25284090909090906
# BERT score: {'label': 'POSITIVE', 'score': 0.996298611164093}
# --------------------------------------------------------------------------------
# Sentence: However, large companies with a long history, including General Motors Company (NYSE: GM), will not relinquish their market share.
# VADER scores: {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.296}
# TextBlob polarity: 0.07142857142857142
# BERT score: {'label': 'NEGATIVE', 'score': 0.9508581161499023}
# --------------------------------------------------------------------------------
# Sentence: On 5 February 2024, we delved into GM's business and financial position, examined the key factors that have previously influenced and are now affecting its stock value, conducted a technical analysis of the shares, and discovered their prospects for 2024 according to expert forecasts.
# VADER scores: {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'compound': 0.7003}
# TextBlob polarity: -0.041666666666666664
# BERT score: {'label': 'POSITIVE', 'score': 0.9247810244560242}
# --------------------------------------------------------------------------------
# Sentence: Founded by William Durant in 1908, General Motors Company designs and manufactures passenger, commercial, and cargo transport.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.02500000000000001
# BERT score: {'label': 'POSITIVE', 'score': 0.9942208528518677}
# --------------------------------------------------------------------------------
# Sentence: It is one of the world’s largest automakers and owns popular brands such as GMC, Chevrolet, Cadillac, and Buick.
# VADER scores: {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.4215}
# TextBlob polarity: 0.3
# BERT score: {'label': 'POSITIVE', 'score': 0.9991950392723083}
# --------------------------------------------------------------------------------
# Sentence: In 2009, the US company underwent bankruptcy and restructuring procedures.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9965993762016296}
# --------------------------------------------------------------------------------
# Sentence: Nowadays, its operations include three main segments: General Motors Company released its Q4 and full-year 2023 report on 30 January 2024.
# VADER scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# TextBlob polarity: 0.10833333333333334
# BERT score: {'label': 'POSITIVE', 'score': 0.9596558213233948}
# --------------------------------------------------------------------------------
# Sentence: GM Q4 2023 results compared to the Q4 2022 statistics: GM full-year 2023 results compared to the 2022 statistics: General Motors Company expects a net profit of 9.8-11.2 billion USD, EPS of 8.50-9.50 USD, and operating cash flow of 18.0-21.0 billion USD in 2024.
# VADER scores: {'neg': 0.0, 'neu': 0.935, 'pos': 0.065, 'compound': 0.4404}
# TextBlob polarity: 0.02500000000000001
# BERT score: {'label': 'NEGATIVE', 'score': 0.9028568267822266}
# --------------------------------------------------------------------------------
# Sentence: GM's guidance for this year reflects hopes of improving financial performance, confidence in its products, and expectations of potential growth in China, alongside a possible increase in demand for electric vehicles, for which CEO Mary Barra predicts a 10% increase in 2024.
# VADER scores: {'neg': 0.03, 'neu': 0.652, 'pos': 0.318, 'compound': 0.9274}
# TextBlob polarity: 0.0
# BERT score: {'label': 'POSITIVE', 'score': 0.9976804256439209}
# --------------------------------------------------------------------------------
# Sentence: General Motors Company’s stock gained 7.8% at the close of the trading session on 30 January, reaching 38.15 USD per unit based on last year’s results and optimistic guidance for this year.
# VADER scores: {'neg': 0.0, 'neu': 0.812, 'pos': 0.188, 'compound': 0.6908}
# TextBlob polarity: 0.02500000000000001
# BERT score: {'label': 'NEGATIVE', 'score': 0.893761157989502}
# --------------------------------------------------------------------------------
# Sentence: Want to trade stocks without commission?
# VADER scores: {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.0772}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9983626008033752}
# --------------------------------------------------------------------------------
# Sentence: Gain access to over 1000 US stocks for commission-free trading on the R StocksTrader platform The United Auto Workers (UAW) strike lasted from 15 September to 31 October 2023, involving over 45,000 workers at General Motors Company, Ford Motor Company, and Stellantis N.V. factories.
# VADER scores: {'neg': 0.031, 'neu': 0.839, 'pos': 0.13, 'compound': 0.6908}
# TextBlob polarity: 0.05000000000000002
# BERT score: {'label': 'NEGATIVE', 'score': 0.9890154004096985}
# --------------------------------------------------------------------------------
# Sentence: This article delved into the reasons behind this strike and discussed who the UAW is.
# VADER scores: {'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'compound': -0.1593}
# TextBlob polarity: -0.4
# BERT score: {'label': 'NEGATIVE', 'score': 0.5770348906517029}
# --------------------------------------------------------------------------------
# Sentence: According to Paul Jacobson, GM's chief financial officer, the strike had a detrimental effect on EBIT for Q4 and the full year 2023, reducing final figures by 0.9 billion USD and 1.1 billion USD, respectively.
# VADER scores: {'neg': 0.042, 'neu': 0.891, 'pos': 0.067, 'compound': 0.2263}
# TextBlob polarity: 0.0875
# BERT score: {'label': 'NEGATIVE', 'score': 0.9992604851722717}
# --------------------------------------------------------------------------------
# Sentence: The stock declined by 19.2% during the strike, plummeting from 33 to 27 USD.
# VADER scores: {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'compound': -0.128}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9994887113571167}
# --------------------------------------------------------------------------------
# Sentence: On 29 November 2023, GM launched an accelerated 10 billion USD share repurchase program, seemingly aimed at restoring investor confidence.
# VADER scores: {'neg': 0.0, 'neu': 0.635, 'pos': 0.365, 'compound': 0.802}
# TextBlob polarity: 0.0
# BERT score: {'label': 'NEGATIVE', 'score': 0.9906524419784546}
# --------------------------------------------------------------------------------
# Sentence: Before the start of the program, the company had 1.37 billion outstanding shares, which decreased to 1.15 billion as of 1 February 2024.
# VADER scores: {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.7351}
# TextBlob polarity: 0.04999999999999999
# BERT score: {'label': 'NEGATIVE', 'score': 0.9910047054290771}
# ...
# Entity: GM (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.05000000000000002
# BERT score: 0.8313527703285217
# --------------------------------------------------------------------------------
# Entity: needs.2 (PERSON)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.5591548085212708
# --------------------------------------------------------------------------------
# Entity: RoboMarkets (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.25
# BERT score: 0.9864161014556885
# --------------------------------------------------------------------------------
# Entity: 100 (CARDINAL)
# VADER score: 0.0
# TextBlob polarity: 0.25
# BERT score: 0.9864161014556885
# --------------------------------------------------------------------------------
# Entity: StocksTrader (ORG)
# VADER score: 0.0
# TextBlob polarity: -0.03749999999999999
# BERT score: 0.9978906512260437
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.0
# TextBlob polarity: -0.03749999999999999
# BERT score: 0.9978906512260437
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.0772
# TextBlob polarity: 0.05000000000000002
# BERT score: 0.7624934315681458
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.275
# BERT score: 0.9956119060516357
# --------------------------------------------------------------------------------
# Entity: RoboMarkets (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.275
# BERT score: 0.9956119060516357
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.4404
# TextBlob polarity: 0.09583333333333335
# BERT score: 0.9628274440765381
# --------------------------------------------------------------------------------
# Entity: Q4 2023 (DATE)
# VADER score: 0.4404
# TextBlob polarity: 0.09583333333333335
# BERT score: 0.9628274440765381
# --------------------------------------------------------------------------------
# Entity: 0.30% (PERCENT)
# VADER score: 0.4404
# TextBlob polarity: 0.09583333333333335
# BERT score: 0.9628274440765381
# --------------------------------------------------------------------------------
# Entity: 42.98 billion USD (MONEY)
# VADER score: 0.4404
# TextBlob polarity: 0.09583333333333335
# BERT score: 0.9628274440765381
# --------------------------------------------------------------------------------
# Entity: 5.15% (PERCENT)
# VADER score: 0.4404
# TextBlob polarity: 0.09583333333333335
# BERT score: 0.9628274440765381
# --------------------------------------------------------------------------------
# Entity: 2.10 billion USD (MONEY)
# VADER score: 0.4404
# TextBlob polarity: 0.09583333333333335
# BERT score: 0.9628274440765381
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.743
# TextBlob polarity: 0.10625000000000001
# BERT score: 0.9961513876914978
# --------------------------------------------------------------------------------
# Entity: 2023 (DATE)
# VADER score: 0.743
# TextBlob polarity: 0.10625000000000001
# BERT score: 0.9961513876914978
# --------------------------------------------------------------------------------
# Entity: 9.64% (PERCENT)
# VADER score: 0.743
# TextBlob polarity: 0.10625000000000001
# BERT score: 0.9961513876914978
# --------------------------------------------------------------------------------
# Entity: 171.84 billion (MONEY)
# VADER score: 0.743
# TextBlob polarity: 0.10625000000000001
# BERT score: 0.9961513876914978
# --------------------------------------------------------------------------------
# Entity: 1.94% (PERCENT)
# VADER score: 0.743
# TextBlob polarity: 0.10625000000000001
# BERT score: 0.9961513876914978
# --------------------------------------------------------------------------------
# Entity: 10.13 billion USD (MONEY)
# VADER score: 0.743
# TextBlob polarity: 0.10625000000000001
# BERT score: 0.9961513876914978
# --------------------------------------------------------------------------------
# Entity: EV (ORG)
# VADER score: 0.3818
# TextBlob polarity: 0.06666666666666668
# BERT score: 0.9996284246444702
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.3818
# TextBlob polarity: 0.06666666666666668
# BERT score: 0.9996284246444702
# --------------------------------------------------------------------------------
# Entity: General Motors' (ORG)
# VADER score: 0.6908
# TextBlob polarity: 0.13863636363636364
# BERT score: 0.998089611530304
# --------------------------------------------------------------------------------
# Entity: EV (ORG)
# VADER score: 0.6908
# TextBlob polarity: 0.13863636363636364
# BERT score: 0.998089611530304
# --------------------------------------------------------------------------------
# Entity: 10% (PERCENT)
# VADER score: 0.6908
# TextBlob polarity: 0.13863636363636364
# BERT score: 0.998089611530304
# --------------------------------------------------------------------------------
# Entity: 2024 (DATE)
# VADER score: 0.6908
# TextBlob polarity: 0.13863636363636364
# BERT score: 0.998089611530304
# --------------------------------------------------------------------------------
# Entity: GM (ORG)
# VADER score: 0.6908
# TextBlob polarity: 0.13863636363636364
# BERT score: 0.998089611530304
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: -0.4215
# TextBlob polarity: 0.016666666666666673
# BERT score: 0.7777878046035767
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.8158
# TextBlob polarity: 0.24583333333333335
# BERT score: 0.9313687086105347
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.5574
# TextBlob polarity: 0.02500000000000001
# BERT score: 0.9993194341659546
# --------------------------------------------------------------------------------
# Entity: GM (ORG)
# VADER score: 0.5574
# TextBlob polarity: 0.02500000000000001
# BERT score: 0.9993194341659546
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.05000000000000002
# BERT score: 0.9993732571601868
# --------------------------------------------------------------------------------
# Entity: GM (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.05000000000000002
# BERT score: 0.9993732571601868
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.02500000000000001
# BERT score: 0.9899564981460571
# --------------------------------------------------------------------------------
# Entity: GM (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.02500000000000001
# BERT score: 0.9899564981460571
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: -0.4215
# TextBlob polarity: 0.125
# BERT score: 0.5989118814468384
# --------------------------------------------------------------------------------
# Entity: UAW (ORG)
# VADER score: 0.4588
# TextBlob polarity: 0.15000000000000002
# BERT score: 0.5650928020477295
# --------------------------------------------------------------------------------
# Entity: General Motors' (ORG)
# VADER score: 0.7003
# TextBlob polarity: 0.13863636363636364
# BERT score: 0.999462902545929
# --------------------------------------------------------------------------------
# Entity: ESG (ORG)
# VADER score: 0.7003
# TextBlob polarity: 0.13863636363636364
# BERT score: 0.999462902545929
# --------------------------------------------------------------------------------
# Entity: The General Motors ESG (ORG)
# VADER score: 0.743
# TextBlob polarity: 0.04166666666666667
# BERT score: 0.9855849146842957
# --------------------------------------------------------------------------------
# Entity: GM (ORG)
# VADER score: 0.743
# TextBlob polarity: 0.04166666666666667
# BERT score: 0.9855849146842957
# --------------------------------------------------------------------------------
# Entity: the Republic of Cyprus (GPE)
# VADER score: 0.25
# TextBlob polarity: 0.05059523809523809
# BERT score: 0.9926706552505493
# --------------------------------------------------------------------------------
# Entity: TradingView (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.961880087852478
# --------------------------------------------------------------------------------
# Entity: Robinhood Markets (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.5
# BERT score: 0.9704407453536987
# --------------------------------------------------------------------------------
# Entity: 2024 (DATE)
# VADER score: 0.0
# TextBlob polarity: 0.5
# BERT score: 0.9704407453536987
# --------------------------------------------------------------------------------
# Entity: HOOD (PRODUCT)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9961062073707581
# --------------------------------------------------------------------------------
# Entity: Robinhood Markets (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.13636363636363635
# BERT score: 0.9417025446891785
# --------------------------------------------------------------------------------
# Entity: IPO (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9678098559379578
# --------------------------------------------------------------------------------
# Entity: 2024 (DATE)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9678098559379578
# --------------------------------------------------------------------------------
# Entity: 2024 (DATE)
# VADER score: 0.0
# TextBlob polarity: 0.5
# BERT score: 0.9359868168830872
# --------------------------------------------------------------------------------
# Entity: IPO (ORG)
# VADER score: -0.2732
# TextBlob polarity: 0.0
# BERT score: 0.9956604838371277
# --------------------------------------------------------------------------------
# Entity: 2024 (DATE)
# VADER score: -0.2732
# TextBlob polarity: 0.0
# BERT score: 0.9956604838371277
# --------------------------------------------------------------------------------
# Entity: Acuity Trading's (PERSON)
# VADER score: 0.0
# TextBlob polarity: 0.1
# BERT score: 0.9503617286682129
# --------------------------------------------------------------------------------
# Entity: Research Terminal (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.1
# BERT score: 0.9503617286682129
# --------------------------------------------------------------------------------
# Entity: AnalysisIQ (GPE)
# VADER score: 0.0
# TextBlob polarity: 0.1
# BERT score: 0.9503617286682129
# --------------------------------------------------------------------------------
# Entity: NewsIQ (GPE)
# VADER score: 0.0
# TextBlob polarity: 0.1
# BERT score: 0.9503617286682129
# --------------------------------------------------------------------------------
# Entity: Calendar (PRODUCT)
# VADER score: 0.0
# TextBlob polarity: 0.1
# BERT score: 0.9503617286682129
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.275
# BERT score: 0.9911940693855286
# --------------------------------------------------------------------------------
# Entity: 2024 (DATE)
# VADER score: 0.0
# TextBlob polarity: 0.275
# BERT score: 0.9911940693855286
# --------------------------------------------------------------------------------
# Entity: GM (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9978578686714172
# --------------------------------------------------------------------------------
# Entity: General Motors (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.09318181818181819
# BERT score: 0.5023815035820007
# --------------------------------------------------------------------------------
# Entity: XAG/USD (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9923932552337646
# --------------------------------------------------------------------------------
# Entity: 2023 (DATE)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9923932552337646
# --------------------------------------------------------------------------------
# Entity: 2024 (DATE)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9874047636985779
# --------------------------------------------------------------------------------
# Entity: 5 (CARDINAL)
# VADER score: 0.2023
# TextBlob polarity: 0.5
# BERT score: 0.9815215468406677
# --------------------------------------------------------------------------------
# Entity: 2023 (DATE)
# VADER score: 0.2023
# TextBlob polarity: 0.5
# BERT score: 0.9815215468406677
# --------------------------------------------------------------------------------
# Entity: AMAM (ORG)
# VADER score: 0.2023
# TextBlob polarity: 0.5
# BERT score: 0.9815215468406677
# --------------------------------------------------------------------------------
# Entity: EYPT (GPE)
# VADER score: 0.2023
# TextBlob polarity: 0.5
# BERT score: 0.9815215468406677
# --------------------------------------------------------------------------------
# Entity: IMGN (GPE)
# VADER score: 0.2023
# TextBlob polarity: 0.5
# BERT score: 0.9815215468406677
# --------------------------------------------------------------------------------
# Entity: GYRE (GPE)
# VADER score: 0.2023
# TextBlob polarity: 0.5
# BERT score: 0.9815215468406677
# --------------------------------------------------------------------------------
# Entity: 2024 (DATE)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9273315668106079
# --------------------------------------------------------------------------------
# Entity: Boeing (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.5
# BERT score: 0.9791412949562073
# --------------------------------------------------------------------------------
# Entity: 2024 (DATE)
# VADER score: 0.0
# TextBlob polarity: 0.5
# BERT score: 0.9791412949562073
# --------------------------------------------------------------------------------
# Entity: BA (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9964343309402466
# --------------------------------------------------------------------------------
# Entity: Boeing (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.13636363636363635
# BERT score: 0.6043918132781982
# --------------------------------------------------------------------------------
# Entity: Mullen Automotive (PERSON)
# VADER score: 0.0
# TextBlob polarity: 0.5
# BERT score: 0.9717130064964294
# --------------------------------------------------------------------------------
# Entity: 2024 (DATE)
# VADER score: 0.0
# TextBlob polarity: 0.5
# BERT score: 0.9717130064964294
# --------------------------------------------------------------------------------
# Entity: MULN (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9928035140037537
# --------------------------------------------------------------------------------
# Entity: Mullen Automotive (PERSON)
# VADER score: 0.0
# TextBlob polarity: 0.13636363636363635
# BERT score: 0.8267425894737244
# --------------------------------------------------------------------------------
# Entity: RoboMarkets Ltd (ORG)
# VADER score: -0.296
# TextBlob polarity: 0.0
# BERT score: 0.9769171476364136
# --------------------------------------------------------------------------------
# Entity: European (NORP)
# VADER score: -0.296
# TextBlob polarity: 0.0
# BERT score: 0.9769171476364136
# --------------------------------------------------------------------------------
# Entity: 191/13 (DATE)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.7968927025794983
# --------------------------------------------------------------------------------
# Entity: RoboMarkets Ltd (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9139487147331238
# --------------------------------------------------------------------------------
# Entity: EU (ORG)
# VADER score: 0.0
# TextBlob polarity: 0.0
# BERT score: 0.9139487147331238
# --------------------------------------------------------------------------------
# Entity: RoboMarkets (ORG)
# VADER score: 0.0
# TextBlob polarity: -0.1
# BERT score: 0.9934145212173462
# --------------------------------------------------------------------------------
